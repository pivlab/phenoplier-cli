# %%
import pandas as pd

data = pd.read_csv("nbs/null_simulations/01_phenotype_generation/data/random_phenotypes_df_40_pcs.phe.tsv", sep="\t")
data.head()
# Out:
#        FID      IID  sex  age  ad_by_proxy  ad_risk_by_proxy  \
# 0  5507516  5507516    1   64            0              0.64
# 1  4449508  4449508    1   68            0              0.64
# 2  2510504  2510504    0   60            0              0.64
# 3  4563542  4563542    0   45            0              0.87
# 4  2170567  2170567    0   45            0              0.64
#
#                                          icd10_codes  has_ad_icd10  \
# 0  R031,K573,R42,K635,K621,E119,Z855,I842,C442,E8...             0
# 1  Z885,I849,Z922,R11,K573,K922,Z092,R074,Z888,Q2...             0
# 2  M5416,K589,F329,R194,R15,F171,M169,E780,M754,F419             0
# 3  T814,W109,M1999,K029,Y838,R69,M2553,T922,Z470,...             0
# 4  Z900,N812,R194,Z966,M179,M543,R103,Z907,Y400,Z...             0
#
#    ethnic_group  sex_chromosome_aneuploidy  ...  pheno990  pheno991  pheno992  \
# 0           1.0                        NaN  ...  0.718638 -0.110123  0.737745
# ...

# %%
# Remove column "illnesses_of_father" and "illnesses_of_mother"
data = data.drop(columns=["illnesses_of_father", "illnesses_of_mother"])

# %%
# Save the processed data
data.to_csv("nbs/null_simulations/01_phenotype_generation/data/trimmed_random_phenotypes_df_40_pcs.phe", sep="\t", index=False)
