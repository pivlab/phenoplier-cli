# %% [markdown]
# ## Description
# It takes a GWAS on a random phenotype and verifies that the Manhattan and QQ-plots look fine (without inflation).

# %%
# Load plotting functions
# %run ../common/plotting_functions.ipynb

# %%
PHENOPLIER_NULLSIM_RESULTS_DIR = Path(os.environ["PHENOPLIER_RESULTS_GLS_NULL_SIMS_UKB_40PCS"])
SPREDIXCAN_DIR = PHENOPLIER_NULLSIM_RESULTS_DIR / "twas" / "spredixcan"
SMULTIXCAN_DIR = PHENOPLIER_NULLSIM_RESULTS_DIR / "twas" / "smultixcan"

# %%
analyze_random_phenotypes_twas_spredixcan(5, SPREDIXCAN_DIR, "spredixcan", "-gtex_v8-mashr-Whole_Blood.csv")
analyze_random_phenotypes_twas_smultixcan(5, SMULTIXCAN_DIR, "smultixcan", "-gtex_v8-mashr-smultixcan.txt")
# Out:
# Using twas directory: /tmp/phenoplier/results/gls/gwas/null_sims/ukb_50pcs/twas/spredixcan with filename suffix: -gtex_v8-mashr-Whole_Blood.csv...
# Phenotype 0: Dimensions = (12511, 14). First 5 rows:
#                 gene     gene_name    zscore  effect_size    pvalue     var_g  \
# 0  ENSG00000125910.5         S1PR4 -3.947639          NaN  0.000079  0.000104
# 1  ENSG00000273759.1  RP4-563E14.1  3.824921          NaN  0.000131  0.065132
# 2  ENSG00000163923.9        RPL39L -3.748353          NaN  0.000178  0.000004
# 3  ENSG00000221995.5         TIAF1 -3.682528          NaN  0.000231  0.024214
# 4  ENSG00000181788.3         SIAH2 -3.563459          NaN  0.000366  0.001093
#
#    pred_perf_r2  pred_perf_pval  pred_perf_qval  n_snps_used  n_snps_in_cov  \
# 0           NaN             NaN             NaN            2            2.0
# 1           NaN             NaN             NaN            2            2.0
# ...
